# %%
import matplotlib.pyplot as plt
import mne
import numpy as np

# %%
# synthetic data

times = np.linspace(0, 1, 250, endpoint=False)
sine = np.sin(20 * np.pi * times)
cosine = np.cos(10 * np.pi * times)
data = np.array([sine, cosine])

info = mne.create_info(ch_names=['10 Hz sine', '5 Hz cosine'],
                       ch_types=['misc'] * 2,
                       sfreq=250)

simulated_raw = mne.io.RawArray(data, info)
simulated_raw.plot(show_scrollbars=False, show_scalebars=False)
# Out:
# Creating RawArray with float64 data, n_channels=2, n_times=250
#     Range : 0 ... 249 =      0.000 ...     0.996 secs
# Ready.
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>
